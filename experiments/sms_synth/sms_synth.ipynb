# %%
from smstools.models import sineModel
import librosa

win_size = 512
threshold = -80 # dB
n_sines = 100
fs = 44100


window = librosa.filters.get_window('flattop', win_size, fftbins=True)


freqs, amps, phases = sineModel.sineModelAnal(
  x,
  fs,
  window,
  win_size,
  win_size//4,
  threshold,
  maxnSines=n_sines,
  minSineDur=0.001,
  freqDevSlope=0.001,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from smstools import sineModel
#       3 freqs, amps, phases = sineModel.sineModelAnal(
#       4   x,
#       5   fs,
#    (...)
#      12   freqDevSlope=0.001,
#      13 )
#
# ImportError: cannot import name 'sineModel' from 'smstools' (unknown location)
